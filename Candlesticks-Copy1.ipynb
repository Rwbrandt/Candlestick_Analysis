# %%
import numpy as np  # noqa
import pandas as pd  # noqa
from pandas import DataFrame
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import plotly.graph_objects as go
import os
from pathlib import Path
import talib as ta
from talib import MA_Type as ma
import pandas as pd

# %%
ticker = "MSFT"
inter = "1m" #crypto has to be every 5 minutes while stocks is 1m

# %%
df = pd.read_csv(
    Path(f"{ticker}_prices_{inter}.csv"),
    parse_dates=True,
    infer_datetime_format=True)

# %%
df = df.set_index(pd.DatetimeIndex(df['Datetime']), drop=True, append=False, inplace=False, verify_integrity=False)

# %%
df
# Out:
#                                             Datetime    Open    High     Low  \
# Datetime
# 2022-01-07 09:30:00-05:00  2022-01-07 09:30:00-05:00  314.15  315.00  313.55
# 2022-01-07 09:31:00-05:00  2022-01-07 09:31:00-05:00  314.51  315.32  314.33
# 2022-01-07 09:32:00-05:00  2022-01-07 09:32:00-05:00  315.24  315.28  314.06
# 2022-01-07 09:33:00-05:00  2022-01-07 09:33:00-05:00  313.50  313.68  313.27
# 2022-01-07 09:34:00-05:00  2022-01-07 09:34:00-05:00  313.54  314.14  313.26
# ...                                              ...     ...     ...     ...
# 2022-01-18 15:56:00-05:00  2022-01-18 15:56:00-05:00  302.20  302.40  302.06
# 2022-01-18 15:57:00-05:00  2022-01-18 15:57:00-05:00  302.21  302.82  302.17
# 2022-01-18 15:58:00-05:00  2022-01-18 15:58:00-05:00  302.54  302.69  302.42
# 2022-01-18 15:59:00-05:00  2022-01-18 15:59:00-05:00  302.61  303.11  302.22
# 2022-01-18 16:00:00-05:00  2022-01-18 16:00:00-05:00  302.65  302.65  302.65
#
# ...

# %%
open = df['Open']
high = df['High']
low = df['Low']
close = df['Close']


Two_Crows = ta.CDL2CROWS(open, high, low, close)
Three_Black_Crows = ta.CDL3BLACKCROWS(open, high, low, close)
Three_Inside_Updown = ta.CDL3INSIDE(open, high, low, close)
Three_Line_Strike = ta.CDL3LINESTRIKE(open, high, low, close)
Three_Outside_UpDown = ta.CDL3OUTSIDE(open, high, low, close)
Three_Stars_In_The_South = ta.CDL3STARSINSOUTH(open, high, low, close)
Three_Advancing_White_Soldiers= ta.CDL3WHITESOLDIERS(open, high, low, close)
Abandoned_Baby = ta.CDLABANDONEDBABY(open, high, low, close, penetration=0)
Advance_Block = ta.CDLADVANCEBLOCK(open, high, low, close)
Belthold = ta.CDLBELTHOLD(open, high, low, close)
Breakaway = ta.CDLBREAKAWAY(open, high, low, close)
Closing_Marubozu = ta.CDLCLOSINGMARUBOZU(open, high, low, close)
Concealing_Baby_Swallow = ta.CDLCONCEALBABYSWALL(open, high, low, close)                           
Counterattack = ta.CDLCOUNTERATTACK(open, high, low, close)                           
Dark_Cloud_Cover = ta.CDLDARKCLOUDCOVER(open, high, low, close, penetration=0)                           
Doji = ta.CDLDOJI(open, high, low, close)                           
Doji_Star = ta.CDLDOJISTAR(open, high, low, close)                           
Dragonfly_Doji = ta.CDLDRAGONFLYDOJI(open, high, low, close)                           
Engulfing_Pattern = ta.CDLENGULFING(open, high, low, close)
Evening_Doji_Star = ta.CDLEVENINGDOJISTAR(open, high, low, close, penetration=0)                           
Evening_Star = ta.CDLEVENINGSTAR(open, high, low, close, penetration=0)                           
UpDown_gap_sidebyside_white_lines = ta.CDLGAPSIDESIDEWHITE(open, high, low, close)                           
Gravestone_Doji = ta.CDLGRAVESTONEDOJI(open, high, low, close)                           
Hammer = ta.CDLHAMMER(open, high, low, close)                          
Hanging_Man = ta.CDLHANGINGMAN(open, high, low, close)                           
Harami_Pattern = ta.CDLHARAMI(open, high, low, close)                           
Harami_Cross_Pattern = ta.CDLHARAMICROSS(open, high, low, close)
HighWave_Candle = ta.CDLHIGHWAVE(open, high, low, close)                           
Hikkake_Pattern = ta.CDLHIKKAKE(open, high, low, close)                           
Modified_Hikkake_Pattern = ta.CDLHIKKAKEMOD(open, high, low, close)                           
Homing_Pigeon = ta.CDLHOMINGPIGEON(open, high, low, close)                           
Identical_Three_Crows = ta.CDLIDENTICAL3CROWS(open, high, low, close)                           
In_Neck_Pattern = ta.CDLINNECK(open, high, low, close)                           
Inverted_Hammer = ta.CDLINVERTEDHAMMER(open, high, low, close)                           
Kicking = ta.CDLKICKING(open, high, low, close)
Kicking_bullbear_determined_by_the_longer_marubozu = ta.CDLKICKINGBYLENGTH(open, high, low, close)                           
Ladder_Bottom = ta.CDLLADDERBOTTOM(open, high, low, close)                           
Long_Legged_Doji = ta.CDLLONGLEGGEDDOJI(open, high, low, close)                           
Long_Line_Candle = ta.CDLLONGLINE(open, high, low, close)                           
Marubozu = ta.CDLMARUBOZU(open, high, low, close)                           
Matching_Low = ta.CDLMATCHINGLOW(open, high, low, close)                           
Mat_Hold = ta.CDLMATHOLD(open, high, low, close, penetration=0)                           
Morning_Doji_Star = ta.CDLMORNINGDOJISTAR(open, high, low, close, penetration=0)                           
Morning_Star = ta.CDLMORNINGSTAR(open, high, low, close, penetration=0)
OnNeck_Pattern = ta.CDLONNECK(open, high, low, close)                           
Piercing_Pattern = ta.CDLPIERCING(open, high, low, close)                           
Rickshaw_Man = ta.CDLRICKSHAWMAN(open, high, low, close)                           
RisingFalling_Three_Methods = ta.CDLRISEFALL3METHODS(open, high, low, close)                           
Separating_Lines = ta.CDLSEPARATINGLINES(open, high, low, close)                           
Shooting_Star = ta.CDLSHOOTINGSTAR(open, high, low, close)                           
Short_Line_Candle = ta.CDLSHORTLINE(open, high, low, close)
Spinning_Top = ta.CDLSPINNINGTOP(open, high, low, close)
Stalled_Pattern = ta.CDLSTALLEDPATTERN(open, high, low, close)
Stick_Sandwich = ta.CDLSTICKSANDWICH(open, high, low, close)
Takuri_Dragonfly_Doji = ta.CDLTAKURI(open, high, low, close)
Tasuki_Gap = ta.CDLTASUKIGAP(open, high, low, close)
Thrusting_Pattern = ta.CDLTHRUSTING(open, high, low, close)
Tristar_Pattern = ta.CDLTRISTAR(open, high, low, close)
Unique_River = ta.CDLUNIQUE3RIVER(open, high, low, close)                           
Upside_Gap_Two_Crows = ta.CDLUPSIDEGAP2CROWS(open, high, low, close)                           
UpsideDownside_Gap_Three_Methods = ta.CDLXSIDEGAP3METHODS(open, high, low, close)

# %%
patterns = df

patterns['Two_Crows'] = Two_Crows
patterns['Three_Black_Crows'] = Three_Black_Crows
patterns['Three_Inside_Updown'] = Three_Inside_Updown
patterns['Three_Line_Strike'] = Three_Line_Strike
patterns['Three_Outside_UpDown'] = Three_Outside_UpDown
patterns['Three_Stars_In_The_South'] = Three_Stars_In_The_South
patterns['Three_Advancing_White_Soldiers'] = Three_Advancing_White_Soldiers
patterns['Abandoned_Baby'] = Abandoned_Baby
patterns['Advance_Block'] = Advance_Block
patterns['Belthold'] = Belthold
patterns['Breakaway'] = Breakaway
patterns['Closing_Marubozu'] = Closing_Marubozu
patterns['Concealing_Baby_Swallow'] = Concealing_Baby_Swallow
patterns['Counterattack'] = Counterattack
patterns['Dark_Cloud_Cover'] = Dark_Cloud_Cover
patterns['Doji'] = Doji
patterns['Doji_Star'] = Doji_Star
patterns['Dragonfly_Doji'] = Dragonfly_Doji
patterns['Engulfing_Pattern'] = Engulfing_Pattern
patterns['Evening_Doji_Star'] = Evening_Doji_Star
patterns['Evening_Star'] = Evening_Star
patterns['UpDown_gap_sidebyside_white_lines'] = UpDown_gap_sidebyside_white_lines
patterns['Gravestone_Doji'] = Gravestone_Doji
patterns['Hammer'] = Hammer
patterns['Hanging_Man'] = Hanging_Man
patterns['Harami_Pattern'] = Harami_Pattern
patterns['Harami_Cross_Pattern'] = Harami_Cross_Pattern
patterns['HighWave_Candle'] = HighWave_Candle
patterns['Hikkake_Pattern'] = Hikkake_Pattern
patterns['Modified_Hikkake_Pattern'] = Modified_Hikkake_Pattern
patterns['Homing_Pigeon'] = Homing_Pigeon
patterns['Identical_Three_Crows'] = Identical_Three_Crows
patterns['In_Neck_Pattern'] = In_Neck_Pattern
patterns['Inverted_Hammer'] = Inverted_Hammer
patterns['Kicking'] = Kicking
patterns['Kicking_bullbear_determined_by_the_longer_marubozu'] = Kicking_bullbear_determined_by_the_longer_marubozu
patterns['Ladder_Bottom'] = Ladder_Bottom
patterns['Long_Legged_Doji'] = Long_Legged_Doji
patterns['Long_Line_Candle'] = Long_Line_Candle
patterns['Marubozu'] = Marubozu
patterns['Matching_Low'] = Matching_Low
patterns['Mat_Hold'] = Mat_Hold
patterns['Morning_Doji_Star'] = Morning_Doji_Star
patterns['Morning_Star'] = Morning_Star
patterns['OnNeck_Pattern'] = OnNeck_Pattern
patterns['Piercing_Pattern'] = Piercing_Pattern
patterns['Rickshaw_Man'] = Rickshaw_Man
patterns['RisingFalling_Three_Methods'] = RisingFalling_Three_Methods
patterns['Separating_Lines'] = Separating_Lines
patterns['Shooting_Star'] = Shooting_Star
patterns['Short_Line_Candle'] = Short_Line_Candle
patterns['Spinning_Top'] = Spinning_Top
patterns['Stalled_Pattern'] = Stalled_Pattern
patterns['Stick_Sandwich'] = Stick_Sandwich
patterns['Takuri_Dragonfly_Doji'] = Takuri_Dragonfly_Doji
patterns['Tasuki_Gap'] = Tasuki_Gap
patterns['Thrusting_Pattern'] = Thrusting_Pattern
patterns['Tristar_Pattern'] = Tristar_Pattern
patterns['Unique_River'] = Unique_River
patterns['Upside_Gap_Two_Crows'] = Upside_Gap_Two_Crows
patterns['UpsideDownside_Gap_Three_Methods'] = UpsideDownside_Gap_Three_Methods

# %%
patterns
# Out:
#                                             Datetime    Open    High     Low  \
# Datetime
# 2022-01-07 09:30:00-05:00  2022-01-07 09:30:00-05:00  314.15  315.00  313.55
# 2022-01-07 09:31:00-05:00  2022-01-07 09:31:00-05:00  314.51  315.32  314.33
# 2022-01-07 09:32:00-05:00  2022-01-07 09:32:00-05:00  315.24  315.28  314.06
# 2022-01-07 09:33:00-05:00  2022-01-07 09:33:00-05:00  313.50  313.68  313.27
# 2022-01-07 09:34:00-05:00  2022-01-07 09:34:00-05:00  313.54  314.14  313.26
# ...                                              ...     ...     ...     ...
# 2022-01-18 15:56:00-05:00  2022-01-18 15:56:00-05:00  302.20  302.40  302.06
# 2022-01-18 15:57:00-05:00  2022-01-18 15:57:00-05:00  302.21  302.82  302.17
# 2022-01-18 15:58:00-05:00  2022-01-18 15:58:00-05:00  302.54  302.69  302.42
# 2022-01-18 15:59:00-05:00  2022-01-18 15:59:00-05:00  302.61  303.11  302.22
# 2022-01-18 16:00:00-05:00  2022-01-18 16:00:00-05:00  302.65  302.65  302.65
#
# ...

# %%
patterns['Candle_Sum'] = patterns.iloc[:,7:67].sum(axis=1)
     

patterns
# Out:
#                                             Datetime    Open    High     Low  \
# Datetime
# 2022-01-07 09:30:00-05:00  2022-01-07 09:30:00-05:00  314.15  315.00  313.55
# 2022-01-07 09:31:00-05:00  2022-01-07 09:31:00-05:00  314.51  315.32  314.33
# 2022-01-07 09:32:00-05:00  2022-01-07 09:32:00-05:00  315.24  315.28  314.06
# 2022-01-07 09:33:00-05:00  2022-01-07 09:33:00-05:00  313.50  313.68  313.27
# 2022-01-07 09:34:00-05:00  2022-01-07 09:34:00-05:00  313.54  314.14  313.26
# ...                                              ...     ...     ...     ...
# 2022-01-18 15:56:00-05:00  2022-01-18 15:56:00-05:00  302.20  302.40  302.06
# 2022-01-18 15:57:00-05:00  2022-01-18 15:57:00-05:00  302.21  302.82  302.17
# 2022-01-18 15:58:00-05:00  2022-01-18 15:58:00-05:00  302.54  302.69  302.42
# 2022-01-18 15:59:00-05:00  2022-01-18 15:59:00-05:00  302.61  303.11  302.22
# 2022-01-18 16:00:00-05:00  2022-01-18 16:00:00-05:00  302.65  302.65  302.65
#
# ...

# %%
# Create a new column in the `trading_df` called "signal" setting its value to zero.
patterns["signal"] = 0.0   

# Create the signal to buy
patterns.loc[(patterns['Candle_Sum'] > 0), "signal"] = 1  

# Create the signal to sell
patterns.loc[(patterns['Candle_Sum'] < 0), "signal"] = -1

# %%
# patterns.to_csv(f"{ticker}_candles_signal.csv")

# %%
patterns.tail(60)
# Out:
#                                             Datetime    Open    High     Low  \
# Datetime
# 2022-01-18 15:01:00-05:00  2022-01-18 15:01:00-05:00  304.19  304.20  303.97
# 2022-01-18 15:02:00-05:00  2022-01-18 15:02:00-05:00  304.03  304.48  304.00
# 2022-01-18 15:03:00-05:00  2022-01-18 15:03:00-05:00  304.46  304.51  303.89
# 2022-01-18 15:04:00-05:00  2022-01-18 15:04:00-05:00  303.99  303.99  303.68
# 2022-01-18 15:05:00-05:00  2022-01-18 15:05:00-05:00  303.82  303.90  303.50
# 2022-01-18 15:06:00-05:00  2022-01-18 15:06:00-05:00  303.70  303.97  303.68
# 2022-01-18 15:07:00-05:00  2022-01-18 15:07:00-05:00  303.98  304.11  303.94
# 2022-01-18 15:08:00-05:00  2022-01-18 15:08:00-05:00  304.05  304.06  303.88
# 2022-01-18 15:09:00-05:00  2022-01-18 15:09:00-05:00  303.93  303.99  303.84
# 2022-01-18 15:10:00-05:00  2022-01-18 15:10:00-05:00  303.88  304.05  303.75
# 2022-01-18 15:11:00-05:00  2022-01-18 15:11:00-05:00  303.98  304.25  303.98
# ...

# %% [markdown]
# # Alexi Pseudo Code
#
# intial_capital = 100000
# shares = 500
#
# transaction
# if round 'close' * shares < remaining cash.shift(-1) and > 0     transaction = 0
# else close * shares
#
# 'remaining cash"  = intial_capital - ('transaction' .cumsum
# if

# %%
# COLUMN
# Initial Capital = Starting Capital aka opening balace
# Buy Amount = 10% (10 consective buys max)
# Sell Amount = 100%
-----
# Trading Capital = liquid cash on hand (funds available to buy)
# Portfolio Returns = total sum profit/loss (running total)
# Daily Portfolio Returns =
# Cumulative Portfolio Returns = Sum of Daily Portfolio Returns
# Transaction Amount = buy/sell price
# Transaction Units (shares/coins) = number of shares/coins bought/sold (Transaction Amount divided by Closing Price)
# Number of Units Owned = Number of shares/coins owned in portfolio
# Portfolio Total = Total value of assets invested (portfolio Total = current closing price * number of units owned)
# Out:
#   File "C:\Users\Sarah\AppData\Local\Temp/ipykernel_7708/28920374.py", line 5
#     -----
#          ^
# SyntaxError: invalid syntax

# %%
inital_capital = 100000
buy_percent = .1
sell_percent = 1

# if patterns["transaction"] < 0:
#     patterns["position"] = patterns["transaction"] * ((buy_percent * inital_capital)/patterns["Close"])

# %%
#SARAH 
Active_Cash = 0
Shares_Purchased = 0
Shares_Owned = 0

def transaction(transaction):
    if df["signal"] > 0:
        Active_Cash = Capital - df['Transaction'] * df['Shares_Purchased']
        Shares_Purchased = round(df["Active_Cash"] * Percent)
        Shares_Owned = df["Shares_Purchased"].cumsum
    elif df["signal"] < 0:
        Active_Cash = df['Shares_Owned'] * df['Close'] + df['ActiveCash']
        Shares_Purchased = 0
        Shares_Owned = df["Shares_Owned"] * df['signal'] - df["Shares_Owned"]
        
patterns['Shares_Purchaced'] = Shares_Purchased
patterns["Tranaction"] = patterns["Close"] * patterns["signal"]
patterns["ActiveCash"] = Active_Cash.cumsum()
patterns['Shares_Owned'] = Shares_Owned
patterns['Portfolio'] = patterns['Shares_Owned'] * patterns['Close']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1348/646425565.py in <module>
#      14         Shares_Owned = df["Shares_Owned"] * df['signal'] - df["Shares_Owned"]
#      15
# ---> 16 patterns['Shares_Purchaced'] = Shares_Purchased
#      17 patterns["Tranaction"] = patterns["Close"] * patterns["signal"]
#      18 patterns["ActiveCash"] = Active_Cash.cumsum()
#
# NameError: name 'patterns' is not defined

# %%
df.head(60)
# Out:
#                                             Datetime    Open    High     Low  \
# Datetime
# 2022-01-07 09:30:00-05:00  2022-01-07 09:30:00-05:00  314.15  315.00  313.55
# 2022-01-07 09:31:00-05:00  2022-01-07 09:31:00-05:00  314.51  315.32  314.33
# 2022-01-07 09:32:00-05:00  2022-01-07 09:32:00-05:00  315.24  315.28  314.06
# 2022-01-07 09:33:00-05:00  2022-01-07 09:33:00-05:00  313.50  313.68  313.27
# 2022-01-07 09:34:00-05:00  2022-01-07 09:34:00-05:00  313.54  314.14  313.26
# 2022-01-07 09:35:00-05:00  2022-01-07 09:35:00-05:00  313.50  313.82  313.00
# 2022-01-07 09:36:00-05:00  2022-01-07 09:36:00-05:00  312.50  312.63  312.49
# 2022-01-07 09:37:00-05:00  2022-01-07 09:37:00-05:00  312.55  312.80  312.51
# 2022-01-07 09:38:00-05:00  2022-01-07 09:38:00-05:00  312.62  313.12  312.62
# 2022-01-07 09:39:00-05:00  2022-01-07 09:39:00-05:00  312.75  313.50  312.75
# 2022-01-07 09:40:00-05:00  2022-01-07 09:40:00-05:00  313.61  313.73  313.49
# ...

# %%
#find amount bought and sold

# patterns['Transaction'] = patterns['Close'] * patterns['signal']
# patterns['Portfolio'] = patterns['Transaction'].cumsum()
# patterns['Daily Returns'] = patterns['Portfolio'].pct_change()
# patterns['Portfolio Cumulative Returns'] = (1 + patterns['Daily Returns'].cumprod() - 1)     



patterns.head(25)
# Out:
#                                             Datetime    Open    High     Low  \
# Datetime
# 2022-01-07 09:30:00-05:00  2022-01-07 09:30:00-05:00  314.15  315.00  313.55
# 2022-01-07 09:31:00-05:00  2022-01-07 09:31:00-05:00  314.51  315.32  314.33
# 2022-01-07 09:32:00-05:00  2022-01-07 09:32:00-05:00  315.24  315.28  314.06
# 2022-01-07 09:33:00-05:00  2022-01-07 09:33:00-05:00  313.50  313.68  313.27
# 2022-01-07 09:34:00-05:00  2022-01-07 09:34:00-05:00  313.54  314.14  313.26
# 2022-01-07 09:35:00-05:00  2022-01-07 09:35:00-05:00  313.50  313.82  313.00
# 2022-01-07 09:36:00-05:00  2022-01-07 09:36:00-05:00  312.50  312.63  312.49
# 2022-01-07 09:37:00-05:00  2022-01-07 09:37:00-05:00  312.55  312.80  312.51
# 2022-01-07 09:38:00-05:00  2022-01-07 09:38:00-05:00  312.62  313.12  312.62
# 2022-01-07 09:39:00-05:00  2022-01-07 09:39:00-05:00  312.75  313.50  312.75
# 2022-01-07 09:40:00-05:00  2022-01-07 09:40:00-05:00  313.61  313.73  313.49
# ...

# %%
# calculate

# %%
weights = np.random.random(len(Returns))
weights /= np.sum(weights)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7708/1236821596.py in <module>
# ----> 1 weights = np.random.random(len(Returns))
#       2 weights /= np.sum(weights)
#
# NameError: name 'Returns' is not defined

# %% [markdown]
# ### Sarah - Machine learning (Neural Net) for 5 day window for predicting prices (x = 5 day window of closing, y = next day's close)

# %% [markdown]
# ### Candlesticks predicting a signal (x = columns 7 : 67 [each indicator], y = signal)

# %% [markdown]
# ### Roger - Monte Carlo 1, determie how to weight each signal  (needs returns column)

# %% [markdown]
# ### Monte Carlo 2 (Optional), which candlestick signals to use    (needs returns column)
